# %% [markdown]
# <a href="https://colab.research.google.com/github/safira123-pixel/PCVK_Genap_2023/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten1.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten1.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (521,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0), pt2=(510,150), color =(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200), pt2=(300,300), color =(0,0,255),thickness=15)
cv.circle(black_img,center=(100,100), radius=50, color =(255,0,0),thickness=8)
cv.line(black_img,pt1=(0,0), pt2=(512,512), color =(255,255,255),thickness=5)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)

plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
verticles = np.array([[100,300], [200,200], [400, 300], [200,400]], dtype = np.int32)
verticles
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = verticles.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts], isClosed=True, color =(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## Pertanyaan ##
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#   jawab :
#
#   jika menggunakan matplotlib pada samping dan bawah gambar tersedia ukuran gambar
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
#   jawab :
#
#   Bedanya terletak pada ukuran gambar yang dibuat dan berpengaruh pada kapasitas file jadi gambar dengan file int32 memiliki penyimpanan lebih besar
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
#
#   jawab :
#
#   google.colab.patches import cv2_imshow digunakan untuk menampilkan gambar yang diambil dari google drive
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
#   jawab :
#
#   Skimage import io digunakan untuk memproses gambar seperti load,read dan write

# %% [markdown]
# ##E. TUGAS ##

# %% [markdown]
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
#
# jawaban : Berubah karena panjang dan lebarnya juga berubah

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-115, kolom 25-120!
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
# 6. Tampilkan image dengan posisi terbalik!

# %%
#2 RED BLUE
img_gb = img
img_gb[:,:,1] = 0
plt.imshow(img_gb)

# %%
#2 GREEN BLUE
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
#3 Tampilkan image baris ke 20-115, kolom 25-120!
img7 = img[20:155,25:120,:]
plt.imshow(img7)

# %%
#4 Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
img7= img[5:30,:,0]
plt.imshow(img7)

# %%
#5 Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  startp = random.randint(0,350)
  endp = random.randint(0,350)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 7
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %%
#6
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.

# %%
# No 7, 8, 9
img_orang = cv.cvtColor(img,cv.COLOR_BGR2RGB)


fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111) 

cv.rectangle(img_orang,pt1=(530,100),pt2=(300,500),color=(0,255,0), thickness=2)

cv.circle(img_orang,center=(410,250),radius=100,color=(255,0,0),thickness=2)

cv.rectangle(img_orang,pt1=(580,400),pt2=(950,300),color=(0,255,0), thickness=2)
cv.putText(img_orang, text='Safira #16',org=(600,370),fontFace=font,fontScale=2,color=(255,0,0),thickness=2,lineType=cv.LINE_AA)

ax.imshow(img_orang)
